# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mlt

# %%
ipl2017=pd.read_csv(r"C:\Users\user\Downloads\ipl\matches.csv")
ipl2017
# Out:
#       id  season           city        date                        team1  \
# 0      1    2017      Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017           Pune  2017-04-06               Mumbai Indians
# 2      3    2017         Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017         Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017      Bangalore  2017-04-08  Royal Challengers Bangalore
# 5      6    2017      Hyderabad  2017-04-09                Gujarat Lions
# 6      7    2017         Mumbai  2017-04-09        Kolkata Knight Riders
# 7      8    2017         Indore  2017-04-10  Royal Challengers Bangalore
# 8      9    2017           Pune  2017-04-11             Delhi Daredevils
# 9     10    2017         Mumbai  2017-04-12          Sunrisers Hyderabad
# 10    11    2017        Kolkata  2017-04-13              Kings XI Punjab
# 11    12    2017      Bangalore  2017-04-14  Royal Challengers Bangalore
# ...

# %% [markdown]
# # Separating ipl 2017 Data's from the whole Dataset

# %%
ipl_2017=ipl2017.head(59)
ipl_2017
# Out:
#     id  season        city        date                        team1  \
# 0    1    2017   Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1    2    2017        Pune  2017-04-06               Mumbai Indians
# 2    3    2017      Rajkot  2017-04-07                Gujarat Lions
# 3    4    2017      Indore  2017-04-08       Rising Pune Supergiant
# 4    5    2017   Bangalore  2017-04-08  Royal Challengers Bangalore
# 5    6    2017   Hyderabad  2017-04-09                Gujarat Lions
# 6    7    2017      Mumbai  2017-04-09        Kolkata Knight Riders
# 7    8    2017      Indore  2017-04-10  Royal Challengers Bangalore
# 8    9    2017        Pune  2017-04-11             Delhi Daredevils
# 9   10    2017      Mumbai  2017-04-12          Sunrisers Hyderabad
# 10  11    2017     Kolkata  2017-04-13              Kings XI Punjab
# 11  12    2017   Bangalore  2017-04-14  Royal Challengers Bangalore
# 12  13    2017      Rajkot  2017-04-14       Rising Pune Supergiant
# ...

# %% [markdown]
# ###### Now we will obtain information about missing values in the dataset

# %%
ipl_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59 entries, 0 to 58
# Data columns (total 18 columns):
# id                 59 non-null int64
# season             59 non-null int64
# city               59 non-null object
# date               59 non-null object
# team1              59 non-null object
# team2              59 non-null object
# toss_winner        59 non-null object
# toss_decision      59 non-null object
# result             59 non-null object
# dl_applied         59 non-null int64
# winner             59 non-null object
# win_by_runs        59 non-null int64
# win_by_wickets     59 non-null int64
# player_of_match    59 non-null object
# venue              59 non-null object
# umpire1            58 non-null object
# umpire2            58 non-null object
# umpire3            0 non-null float64
# dtypes: float64(1), int64(5), object(12)
# memory usage: 8.4+ KB

# %% [markdown]
# #### Performing a simple summary statistics

# %%
ipl_2017.describe()
# Out:
#               id  season  dl_applied  win_by_runs  win_by_wickets  umpire3
# count  59.000000    59.0   59.000000    59.000000       59.000000      0.0
# mean   30.000000  2017.0    0.016949    13.355932        3.457627      NaN
# std    17.175564     0.0    0.130189    26.796656        3.490490      NaN
# min     1.000000  2017.0    0.000000     0.000000        0.000000      NaN
# 25%    15.500000  2017.0    0.000000     0.000000        0.000000      NaN
# 50%    30.000000  2017.0    0.000000     0.000000        4.000000      NaN
# 75%    44.500000  2017.0    0.000000    15.000000        7.000000      NaN
# max    59.000000  2017.0    1.000000   146.000000       10.000000      NaN

# %% [markdown]
# #### Retrieving match details won by maximum margin in term of runs

# %%
ipl_2017.iloc[ipl_2017['win_by_runs'].idxmax()]
# Out:
# id                               44
# season                         2017
# city                          Delhi
# date                     2017-05-06
# team1                Mumbai Indians
# team2              Delhi Daredevils
# toss_winner        Delhi Daredevils
# toss_decision                 field
# result                       normal
# dl_applied                        0
# winner               Mumbai Indians
# win_by_runs                     146
# win_by_wickets                    0
# player_of_match         LMP Simmons
# venue              Feroz Shah Kotla
# umpire1                 Nitin Menon
# umpire2                   CK Nandan
# umpire3                         NaN
# Name: 43, dtype: object

# %% [markdown]
# #### Team with most wins batting Second

# %%
ipl_2017.iloc[ipl_2017['win_by_wickets'].idxmax()]['winner']
# Out:
# 'Kolkata Knight Riders'

# %% [markdown]
# ##### Team with most wins batting First

# %%
ipl_2017.iloc[ipl_2017['win_by_runs'].idxmax()]['winner']
# Out:
# 'Mumbai Indians'

# %% [markdown]
# #### Has Toss-winning helped in Match-winning?

# %%
Winner=ipl_2017['toss_winner']==ipl_2017['winner']
plot=Winner.value_counts()
plot
# Out:
# True     34
# False    25
# dtype: int64

# %%
import seaborn as sns
sns.countplot(Winner)

# %% [markdown]
# #### Team and number of their wins

# %%
Team_name=ipl_2017['winner']

# %%
winner_graph=Team_name.value_counts()
winner_graph
# Out:
# Mumbai Indians                 12
# Rising Pune Supergiant         10
# Kolkata Knight Riders           9
# Sunrisers Hyderabad             8
# Kings XI Punjab                 7
# Delhi Daredevils                6
# Gujarat Lions                   4
# Royal Challengers Bangalore     3
# Name: winner, dtype: int64

# %%
sns.countplot(y=Team_name,orient='h')

# %% [markdown]
# #### Number of Matches hosted by every cities

# %%
city_name=ipl_2017['city']

# %%
sns.countplot(y=city_name,orient='h')

# %% [markdown]
# #### Match Results

# %%
labels=ipl_2017['result'].value_counts().index
values=ipl_2017['result'].value_counts().values

# %%
plt.pie(values,labels=labels,startangle=0)
plt.show()

# %% [markdown]
# #### Preferred Decision after Winning the toss

# %%
Toss_decision=ipl_2017['toss_decision']

# %%
labels=ipl_2017['toss_decision'].value_counts().index
values=ipl_2017['toss_decision'].value_counts().values
plt.pie(values,labels=labels,startangle=90)
plt.show()

# %%
Man_of_the_match=ipl_2017['player_of_match']
Man_of_the_match.value_counts()
# Out:
# NM Coulter-Nile      3
# BA Stokes            3
# Sandeep Sharma       2
# JD Unadkat           2
# RV Uthappa           2
# N Rana               2
# SP Narine            2
# AJ Tye               2
# Rashid Khan          2
# KH Pandya            2
# B Kumar              1
# SS Iyer              1
# S Dhawan             1
# HM Amla              1
# RR Pant              1
# LH Ferguson          1
# DR Smith             1
# KK Nair              1
# Yuvraj Singh         1
# WP Saha              1
# RA Tripathi          1
# HV Patel             1
# SK Raina             1
# CJ Anderson          1
# SV Samson            1
# CA Lynn              1
# SPD Smith            1
# RG Sharma            1
# Mohammed Siraj       1
# GJ Maxwell           1
# Mohammed Shami       1
# KV Sharma            1
# Washington Sundar    1
# KA Pollard           1
# AR Patel             1
# CH Gayle             1
# MS Dhoni             1
# LMP Simmons          1
# MJ McClenaghan       1
# DA Warner            1
# ...

# %%
sns.countplot(y=Man_of_the_match,orient='h')
